# %%
import re

# %%
file_path = '/Users/madiraa/Desktop/columbia_poan/spring_2024/program_evaluation/final_project/public_comment_may_26.txt'

with open(file_path, 'r') as txt_file:
    text_content = txt_file.read()

# %%
text_content
# Out:
# "[Madison Raasch] 14:52:05\nOkay. Okay.\n\n[Madison Raasch] 14:54:36\nNo, Oh Yeah.\n\n[Madison Raasch] 14:54:50\nPolice appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.\n\n[Madison Raasch] 14:54:58\nHowever, Food Not Bombs recently celebrated its fortieth anniversary and it serves hundreds of people.\n\n[Madison Raasch] 14:55:00\nJust do that.\n\n[Madison Raasch] 14:55:04\nYeah. Yeah. Okay. Yeah.\n\n[Madison Raasch] 14:55:05\nMany hours a day. All communications is an opportunity for members of the public to speak to us on items that are not on our agenda.\n\n[Madison Raasch] 14:55:14\nIf you're interested in addressing the council. Based call the number that you see on your screen. If the first number you call busy, please try other numbers until you get through.\n\n[Madison Raasch] 14:55:16\nYeah.\n\n[Madison Raasch] 14:55:23\nYeah.\n\n[Madison Raasch] 14:55:24\nIf you're interested in addressing the council, please press star not on your phone. Once you've entered the meeting to raise your hand and you'll have 2\xa0min to speak.\n\n[Madison Raasch] 14:55:26\nThank you.\n\n[Madison Raasch] 14:55:30\nYes.\n\n[Madison Raasch] 14:55:34\n2 times speak, you'll hear an announcement. We request that you clearly and slowly state your name before making the comment so that we can accurately capture it in the meeting, the comments so that we can accurately capture it in the meeting minute so that we can accurately capture it in the meeting minute, however, did not require that.\n\n[Madison Raasch] 14:55:47\nPlease remember this is a time for Calgary to hear from the public. We will not be taking dialogue.\n\n[Madison Raasch] 14:55:47\nYeah. Okay. Yeah. Hello.\n\n[Madison Raasch] 14:55:53\nAt table we will address the questions raised at the end of oral communications. I'd like to ask.\n\n[Madison Raasch] 14:55:59\nRobert North from Huff has reached out to us early to request 4\xa0min. So Robert North, if you're listening, when it's your time to speak, please make yourself known so that we can give you the appropriate amount of time.\n\n[Madison Raasch] 14:56:01\nYes.\n\n[Madison Raasch] 14:56:06\nOkay.\n\n[Madison Raasch] 14:56:09\nYeah. Yeah. Okay. The little buddy.\n\n[Madison Raasch] 14:56:15\nWith that, I will start while communications.\n\n[Madison Raasch] 14:56:21\nOkay, you're on the line. Hi, this is Robert North, yes. So Homeless United again.\n\n[Madison Raasch] 14:56:22\nOkay. Can you.\n\n[Madison Raasch] 14:56:27\nMaintenance was declared police appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.\n\n[Madison Raasch] 14:56:34\nOkay.\n\n[Madison Raasch] 14:56:37\nHowever, food not bombs recently celebrated its fortieth anniversary and hundreds of people. Many hours a day.\n\n[Madison Raasch] 14:56:39\nYeah. Okay. Yeah. Yeah.\n\n[Madison Raasch] 14:56:47\nAnd it's time, it's time the mayor acknowledged this and declared next week food not bombs appreciation week.\n\n[Madison Raasch] 14:56:56\nOkay. Yeah. Okay. Yeah.\n\n[Madison Raasch] 14:56:56\nThey've taken action, they provided food. Hotel vouchers, survival services. When the police contributions were forced illegal relocations and fences.\n\n[Madison Raasch] 14:57:07\nThank you.\n\n[Madison Raasch] 14:57:08\nCity Council as well as predecessors says a regular habit of rubber stamping with staffs presentations. This is another concern I have.\n\n[Madison Raasch] 14:57:17\nYeah Hey.\n\n[Madison Raasch] 14:57:17\nAnd the current COVID crisis, city managers, seriously threatening the health and welfare of those outside. And without exception or debate received the thumbs up from a complacent Compleasant and Compliant City Council.\n\n[Madison Raasch] 14:57:26\nOkay.\n\n[Madison Raasch] 14:57:30\nThis is a dangerous situation in the community that wants real democratic process, public input and a significant discussio ...

# %%
# Preprocessing steps
text_content = text_content.replace('\n', '')
print("After removing newline characters:", text_content)

text_content = re.sub(r'\d+', '', text_content)
print("After removing digits:", text_content)

text_content_lower = text_content.lower()
print("Lowercased text:", text_content_lower)

# Attempt to remove "madison raasch" (case-insensitive)
text_content_lower = re.sub(r'madison\s+raasch', '', text_content_lower, flags=re.IGNORECASE)
print("After removing 'madison raasch':", text_content_lower)
# Out:
# After removing newline characters: [Madison Raasch] ::Okay. Okay.[Madison Raasch] ::No, Oh Yeah.[Madison Raasch] ::Police appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.[Madison Raasch] ::However, Food Not Bombs recently celebrated its fortieth anniversary and it serves hundreds of people.[Madison Raasch] ::Just do that.[Madison Raasch] ::Yeah. Yeah. Okay. Yeah.[Madison Raasch] ::Many hours a day. All communications is an opportunity for members of the public to speak to us on items that are not on our agenda.[Madison Raasch] ::If you're interested in addressing the council. Based call the number that you see on your screen. If the first number you call busy, please try other numbers until you get through.[Madison Raasch] ::Yeah.[Madison Raasch] ::Yeah.[Madison Raasch] ::If you're interested in addressing the council, please press star not on your phone. Once you've entered the meeting to raise your hand and you'll have  min to speak.[Madison Raasch] ::Thank you.[Madison Raasch] ::Yes.[Madison Raasch] :: times speak, you'll hear an announcement. We request that you clearly and slowly state your name before making the comment so that we can accurately capture it in the meeting, the comments so that we can accurately capture it in the meeting minute so that we can accurately capture it in the meeting minute, however, did not require that.[Madison Raasch] ::Please remember this is a time for Calgary to hear from the public. We will not be taking dialogue.[Madison Raasch] ::Yeah. Okay. Yeah. Hello.[Madison Raasch] ::At table we will address the questions raised at the end of oral communications. I'd like to ask.[Madison Raasch] ::Robert North from Huff has reached out to us early to request  min. So Robert North, if you're listening, when it's your time to speak, please make yourself known so that we can give you the appropriate amount of time.[Madison Raasch] ::Yes.[Madison Raasch] ::Okay.[Madison Raasch] ::Yeah. Yeah. Okay. The little buddy.[Madison Raasch] ::With that, I will start while communications.[Madison Raasch] ::Okay, you're on the line. Hi, this is Robert North, yes. So Homeless United again.[Madison Raasch] ::Okay. Can you.[Madison Raasch] ::Maintenance was declared police appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.[Madison Raasch] ::Okay.[Madison Raasch] ::However, food not bombs recently celebrated its fortieth anniversary and hundreds of people. Many hours a day.[Madison Raasch] ::Yeah. Okay. Yeah. Yeah.[Madison Raasch] ::And it's time, it's time the mayor acknowledged this and declared next week food not bombs appreciation week.[Madison Raasch] ::Okay. Yeah. Okay. Yeah.[Madison Raasch] ::They've taken action, they provided food. Hotel vouchers, survival services. When the police contributions were forced illegal relocations and fences.[Madison Raasch] ::Thank you.[Madison Raasch] ::City Council as well as predecessors says a regular habit of rubber stamping with staffs presentations. This is another concern I have.[Madison Raasch] ::Yeah Hey.[Madison Raasch] ::And the current COVID crisis, city managers, seriously threatening the health and welfare of those outside. And without exception or debate received the thumbs up from a complacent Compleasant and Compliant City Council.[Madison Raasch] ::Okay.[Madison Raasch] ::This is a dangerous situation in the community that wants real democratic process, public input and a significant discussion of important issues.[Madison Raasch] ::Yeah.[Madison Raasch] ::Do your jobs. We heard the mayor's regular announcement gagging any public input, comment, or questions.[Madison Raasch] ::Good.[Madison Raasch] ::Oh.[Madison Raasch] ::On what is probably the most important section of the public meeting reports by the city manager and the city attorney who heard it again today if we were listening.[Madison Raasch] ...
# After removing digits: [Madison Raasch] ::Okay. Okay.[Madison Raasch] ::No, Oh Yeah.[Madison Raasch] ::Police appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.[Madison Raasch] ::However, Food Not Bombs recently celebrated its fortieth anniversary and it serves hundreds of people.[Madison Raasch] ::Just do that.[Madison Raasch] ::Yeah. Yeah. Okay. Yeah.[Madison Raasch] ::Many hours a day. All communications is an opportunity for members of the public to speak to us on items that are not on our agenda.[Madison Raasch] ::If you're interested in addressing the council. Based call the number that you see on your screen. If the first number you call busy, please try other numbers until you get through.[Madison Raasch] ::Yeah.[Madison Raasch] ::Yeah.[Madison Raasch] ::If you're interested in addressing the council, please press star not on your phone. Once you've entered the meeting to raise your hand and you'll have  min to speak.[Madison Raasch] ::Thank you.[Madison Raasch] ::Yes.[Madison Raasch] :: times speak, you'll hear an announcement. We request that you clearly and slowly state your name before making the comment so that we can accurately capture it in the meeting, the comments so that we can accurately capture it in the meeting minute so that we can accurately capture it in the meeting minute, however, did not require that.[Madison Raasch] ::Please remember this is a time for Calgary to hear from the public. We will not be taking dialogue.[Madison Raasch] ::Yeah. Okay. Yeah. Hello.[Madison Raasch] ::At table we will address the questions raised at the end of oral communications. I'd like to ask.[Madison Raasch] ::Robert North from Huff has reached out to us early to request  min. So Robert North, if you're listening, when it's your time to speak, please make yourself known so that we can give you the appropriate amount of time.[Madison Raasch] ::Yes.[Madison Raasch] ::Okay.[Madison Raasch] ::Yeah. Yeah. Okay. The little buddy.[Madison Raasch] ::With that, I will start while communications.[Madison Raasch] ::Okay, you're on the line. Hi, this is Robert North, yes. So Homeless United again.[Madison Raasch] ::Okay. Can you.[Madison Raasch] ::Maintenance was declared police appreciation weak and indeed I heard they were giving out several dozen sandwiches a week at some point and I'm glad to hear that.[Madison Raasch] ::Okay.[Madison Raasch] ::However, food not bombs recently celebrated its fortieth anniversary and hundreds of people. Many hours a day.[Madison Raasch] ::Yeah. Okay. Yeah. Yeah.[Madison Raasch] ::And it's time, it's time the mayor acknowledged this and declared next week food not bombs appreciation week.[Madison Raasch] ::Okay. Yeah. Okay. Yeah.[Madison Raasch] ::They've taken action, they provided food. Hotel vouchers, survival services. When the police contributions were forced illegal relocations and fences.[Madison Raasch] ::Thank you.[Madison Raasch] ::City Council as well as predecessors says a regular habit of rubber stamping with staffs presentations. This is another concern I have.[Madison Raasch] ::Yeah Hey.[Madison Raasch] ::And the current COVID crisis, city managers, seriously threatening the health and welfare of those outside. And without exception or debate received the thumbs up from a complacent Compleasant and Compliant City Council.[Madison Raasch] ::Okay.[Madison Raasch] ::This is a dangerous situation in the community that wants real democratic process, public input and a significant discussion of important issues.[Madison Raasch] ::Yeah.[Madison Raasch] ::Do your jobs. We heard the mayor's regular announcement gagging any public input, comment, or questions.[Madison Raasch] ::Good.[Madison Raasch] ::Oh.[Madison Raasch] ::On what is probably the most important section of the public meeting reports by the city manager and the city attorney who heard it again today if we were listening.[Madison Raasch] ::Okay.[Mad ...
# Lowercased text: [madison raasch] ::okay. okay.[madison raasch] ::no, oh yeah.[madison raasch] ::police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i'm glad to hear that.[madison raasch] ::however, food not bombs recently celebrated its fortieth anniversary and it serves hundreds of people.[madison raasch] ::just do that.[madison raasch] ::yeah. yeah. okay. yeah.[madison raasch] ::many hours a day. all communications is an opportunity for members of the public to speak to us on items that are not on our agenda.[madison raasch] ::if you're interested in addressing the council. based call the number that you see on your screen. if the first number you call busy, please try other numbers until you get through.[madison raasch] ::yeah.[madison raasch] ::yeah.[madison raasch] ::if you're interested in addressing the council, please press star not on your phone. once you've entered the meeting to raise your hand and you'll have  min to speak.[madison raasch] ::thank you.[madison raasch] ::yes.[madison raasch] :: times speak, you'll hear an announcement. we request that you clearly and slowly state your name before making the comment so that we can accurately capture it in the meeting, the comments so that we can accurately capture it in the meeting minute so that we can accurately capture it in the meeting minute, however, did not require that.[madison raasch] ::please remember this is a time for calgary to hear from the public. we will not be taking dialogue.[madison raasch] ::yeah. okay. yeah. hello.[madison raasch] ::at table we will address the questions raised at the end of oral communications. i'd like to ask.[madison raasch] ::robert north from huff has reached out to us early to request  min. so robert north, if you're listening, when it's your time to speak, please make yourself known so that we can give you the appropriate amount of time.[madison raasch] ::yes.[madison raasch] ::okay.[madison raasch] ::yeah. yeah. okay. the little buddy.[madison raasch] ::with that, i will start while communications.[madison raasch] ::okay, you're on the line. hi, this is robert north, yes. so homeless united again.[madison raasch] ::okay. can you.[madison raasch] ::maintenance was declared police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i'm glad to hear that.[madison raasch] ::okay.[madison raasch] ::however, food not bombs recently celebrated its fortieth anniversary and hundreds of people. many hours a day.[madison raasch] ::yeah. okay. yeah. yeah.[madison raasch] ::and it's time, it's time the mayor acknowledged this and declared next week food not bombs appreciation week.[madison raasch] ::okay. yeah. okay. yeah.[madison raasch] ::they've taken action, they provided food. hotel vouchers, survival services. when the police contributions were forced illegal relocations and fences.[madison raasch] ::thank you.[madison raasch] ::city council as well as predecessors says a regular habit of rubber stamping with staffs presentations. this is another concern i have.[madison raasch] ::yeah hey.[madison raasch] ::and the current covid crisis, city managers, seriously threatening the health and welfare of those outside. and without exception or debate received the thumbs up from a complacent compleasant and compliant city council.[madison raasch] ::okay.[madison raasch] ::this is a dangerous situation in the community that wants real democratic process, public input and a significant discussion of important issues.[madison raasch] ::yeah.[madison raasch] ::do your jobs. we heard the mayor's regular announcement gagging any public input, comment, or questions.[madison raasch] ::good.[madison raasch] ::oh.[madison raasch] ::on what is probably the most important section of the public meeting reports by the city manager and the city attorney who heard it again today if we were listening.[madison raasch] ::okay.[madison r ...
# After removing 'madison raasch': [] ::okay. okay.[] ::no, oh yeah.[] ::police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i'm glad to hear that.[] ::however, food not bombs recently celebrated its fortieth anniversary and it serves hundreds of people.[] ::just do that.[] ::yeah. yeah. okay. yeah.[] ::many hours a day. all communications is an opportunity for members of the public to speak to us on items that are not on our agenda.[] ::if you're interested in addressing the council. based call the number that you see on your screen. if the first number you call busy, please try other numbers until you get through.[] ::yeah.[] ::yeah.[] ::if you're interested in addressing the council, please press star not on your phone. once you've entered the meeting to raise your hand and you'll have  min to speak.[] ::thank you.[] ::yes.[] :: times speak, you'll hear an announcement. we request that you clearly and slowly state your name before making the comment so that we can accurately capture it in the meeting, the comments so that we can accurately capture it in the meeting minute so that we can accurately capture it in the meeting minute, however, did not require that.[] ::please remember this is a time for calgary to hear from the public. we will not be taking dialogue.[] ::yeah. okay. yeah. hello.[] ::at table we will address the questions raised at the end of oral communications. i'd like to ask.[] ::robert north from huff has reached out to us early to request  min. so robert north, if you're listening, when it's your time to speak, please make yourself known so that we can give you the appropriate amount of time.[] ::yes.[] ::okay.[] ::yeah. yeah. okay. the little buddy.[] ::with that, i will start while communications.[] ::okay, you're on the line. hi, this is robert north, yes. so homeless united again.[] ::okay. can you.[] ::maintenance was declared police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i'm glad to hear that.[] ::okay.[] ::however, food not bombs recently celebrated its fortieth anniversary and hundreds of people. many hours a day.[] ::yeah. okay. yeah. yeah.[] ::and it's time, it's time the mayor acknowledged this and declared next week food not bombs appreciation week.[] ::okay. yeah. okay. yeah.[] ::they've taken action, they provided food. hotel vouchers, survival services. when the police contributions were forced illegal relocations and fences.[] ::thank you.[] ::city council as well as predecessors says a regular habit of rubber stamping with staffs presentations. this is another concern i have.[] ::yeah hey.[] ::and the current covid crisis, city managers, seriously threatening the health and welfare of those outside. and without exception or debate received the thumbs up from a complacent compleasant and compliant city council.[] ::okay.[] ::this is a dangerous situation in the community that wants real democratic process, public input and a significant discussion of important issues.[] ::yeah.[] ::do your jobs. we heard the mayor's regular announcement gagging any public input, comment, or questions.[] ::good.[] ::oh.[] ::on what is probably the most important section of the public meeting reports by the city manager and the city attorney who heard it again today if we were listening.[] ::okay.[] ::there is no public questioning of these powerful people and the staff they work with whose frequently reactionary agenda reflects the interests of its own bureaucracy, private developers, select and favored nonprofits, and its own powerful department heads.[] ::okay. thank you. okay.[] ::yeah. okay.[] ::now last year several council members tried to let some air and light into this process. they tried to take the agenda making process out of the back room.[] ::okay.[] ::okay. good.[] ::there was even rumors of a progressive majority on the city council at that time. but apparently one ...

# %%
# counts occurences of the word "oakland" in the text
oakland_count = text_content_lower.count('oakland')
oakland_count
# Out:
# 0

# %%
# counts the occurance of "name" as a (somewhat shitty) proxy to measure how many caller there were in the meeting
name_count = text_content_lower.count('name')
name_count
# Out:
# 5

# %%
# Keyword to search for
keyword = 'oakland'

# Split the text into words
words = re.findall(r'\b\w+\b', text_content_lower.lower())

# Find the indices of occurrences of the keyword
indices = [i for i, word in enumerate(words) if word == keyword]

# Extract 40-grams for each occurrence of the keyword
forty_grams = []
for idx in indices:
    start_idx = max(0, idx - 30)
    end_idx = min(len(words), idx + 30)  # +21 to include the word "oakland"
    forty_gram = ' '.join(words[start_idx:end_idx])
    forty_grams.append(forty_gram)

# Print the 40-grams
for idx, gram in enumerate(forty_grams, start=1):
    print(f"{idx}. {gram}")

# %%
# Keyword to search for
keyword = 'police'

# Split the text into words
words = re.findall(r'\b\w+\b', text_content_lower.lower())

# Find the indices of occurrences of the keyword
indices = [i for i, word in enumerate(words) if word == keyword]

# Extract 40-grams for each occurrence of the keyword
forty_grams = []
for idx in indices:
    start_idx = max(0, idx - 25)
    end_idx = min(len(words), idx + 25)  # +21 to include the word "police"
    forty_gram = ' '.join(words[start_idx:end_idx])
    forty_grams.append(forty_gram)

# Print the 40-grams
for idx, gram in enumerate(forty_grams, start=1):
    print(f"{idx}. {gram}")
# Out:
# 1. okay okay no oh yeah police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i m glad to hear
# 2. start while communications okay you re on the line hi this is robert north yes so homeless united again okay can you maintenance was declared police appreciation weak and indeed i heard they were giving out several dozen sandwiches a week at some point and i m glad to hear
# 3. declared next week food not bombs appreciation week okay yeah okay yeah they ve taken action they provided food hotel vouchers survival services when the police contributions were forced illegal relocations and fences thank you city council as well as predecessors says a regular habit of rubber stamping with staffs
